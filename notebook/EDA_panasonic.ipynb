# %%
import os
import json
from pathlib import Path

import util_1 as util
# Out:
# cwd:  /content/drive/MyDrive/Colab_Notebooks/kaggle/panasonic/notebook

# %%
os.chdir('/content/drive/MyDrive/Colab_Notebooks/kaggle/panasonic/')
os.getcwd()
# Out:
# '/content/drive/MyDrive/Colab_Notebooks/kaggle/panasonic'

# %% [markdown]
# # ・train, valの矩形と多角形のデータを分ける

# %%
train_anno_path = list(Path('./data/train_annotations').glob('*.json'))

sample_json_path = train_anno_path[0]

sample_json = util.read_json(str(sample_json_path))
sample_json['labe']
# Out:
# dict_keys(['labels'])

# %% [markdown]
# # ・画像サイズを[896 * 896]に変える
